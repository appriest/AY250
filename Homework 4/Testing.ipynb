# %%
'''This is my practice .ipynb, used to test out different functions that might be helpful for this HW.'''
# Out:
# 'This is my practice .ipynb, used to test out different functions that might be helpful for this HW.'

# %%
import skimage
import scipy as sp
import numpy as np
from scipy import ndimage as img
import matplotlib.image as img1
import matplotlib.pyplot as plt

# %%
im = img.imread('50_categories/airplanes/airplanes_0001.jpg')

# %%
# %pylab inline
plt.imshow(im,cmap=cm.gray)
plt.imshow(median(im,axis=2))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.shape(im)
# Out:
# (164, 398, 3)

# %%
import computerVisionMethods as cvm
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-8ce7dc17dd55> in <module>()
# ----> 1 import computerVisionMethods as cvm
#
# /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/computerVisionMethods.py in <module>()
#     121                 im = skiData.imread(im_path)
#     122                 im_obj = imageToClassify(im)
# --> 123                 features[i,0] = dirs
#     124                 features[i,1] = imageToClassify.size()
#     125
#
# TypeError: list indices must be integers, not tuple
# Loading files from path: /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/airplanes/

# %%
obj = cvm.imageToClassify(im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-617f9212f8b9> in <module>()
# ----> 1 obj = cvm.imageToClassify(im)
#
# NameError: name 'cvm' is not defined

# %%
import skimage.measure as meas

# %%
coords = obj.corner_det()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-9bf3874de6f8> in <module>()
# ----> 1 coords = obj.corner_det()
#
# NameError: name 'obj' is not defined

# %%
coords
# Out:
# (array([[ 1.36918055,  1.3691036 ,  0.41693151, ...,  0.41693151,
#          1.3691036 ,  1.36918055],
#        [ 1.3691036 ,  1.57457535,  0.60254905, ...,  0.60254905,
#          1.57457535,  1.3691036 ],
#        [ 0.41693151,  0.60254905,  0.41934438, ...,  0.41934438,
#          0.60254905,  0.41693151],
#        ...,
#        [ 0.41693151,  0.60254905,  0.41934438, ...,  0.41934438,
#          0.60254905,  0.41693151],
#        [ 1.3691036 ,  1.57457535,  0.60254905, ...,  0.60254905,
#          1.57457535,  1.3691036 ],
#        [ 1.36918055,  1.3691036 ,  0.41693151, ...,  0.41693151,
#          1.3691036 ,  1.36918055]]),
#  array([[ 0.81724956,  0.74348247,  0.25053553, ...,  0.25053553,
#          0.74348247,  0.81724956],
#        [ 0.74348247,  0.97346638,  0.53748157, ...,  0.53748157,
#          0.97346638,  0.74348247],
#        [ 0.25053553,  0.53748157,  0.99902338, ...,  0.99902338,
#          0.53748157,  0.25053553],
#        ...,
# ...

# %%
np.shape(coords)
# Out:
# (2, 164, 398)

# %%
import skimage.feature as ft

hg = ft.hog(median(im,axis=2))

# %%
shape(hg)
# Out:
# (68526,)

# %%
hg_hist = plt.hist(hg,bins=1000)

# %%
sum(hg_hist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-f3e8e295b952> in <module>()
# ----> 1 sum(hg_hist)
#
# /Users/Anders/anaconda/python.app/Contents/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1508         except AttributeError:
#    1509             return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1510                                 out=out, keepdims=keepdims)
#    1511         # NOTE: Dropping the keepdims parameters here...
#    1512         return sum(axis=axis, dtype=dtype, out=out)
#
# /Users/Anders/anaconda/python.app/Contents/lib/python2.7/site-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      16 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#      17     return um.add.reduce(a, axis=axis, dtype=dtype,
# ...

# %%
hg_hist[0][0]
# Out:
# 16299

# %%
im2 = img.imread('50_categories/blimp/blimp_0001.jpg')

# %%
hg = ft.hog(median(im2,axis=2))

# %%
hg_hist = plt.hist(hg,bins=1000)

# %%
import os.path
import os
import matplotlib.image as img

paths = ['/Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/']

for path in paths:
    for files in os.listdir(path):
        if files[0]!='.':
            print files
# Out:
# airplanes
# bat
# bear
# blimp
# camel
# comet
# conch
# cormorant
# crab
# dog
# dolphin
# duck
# elephant
# elk
# frog
# galaxy
# giraffe
# goat
# goldfish
# goose
# gorilla
# helicopter
# horse
# hot-air-balloon
# hummingbird
# iguana
# kangaroo
# killer-whale
# leopards
# llama
# mars
# mussels
# octopus
# ostrich
# owl
# penguin
# porcupine
# raccoon
# saturn
# skunk
# snail
# snake
# speed-boat
# starfish
# swan
# teddy-bear
# toad
# triceratops
# unicorn
# zebra

# %%
import os
import os.path
import scipy.ndimage as img
import skimage.data as skiData

path = os.getcwd()
path += '/50_categories/'

for dirs in os.listdir(path):
    if dirs[0] != '.':
        cat_path = path + dirs +'/'
        print 'Loading files from path:', cat_path
        for files in os.listdir(cat_path):
            if files[0] != '.' and os.path.isfile(cat_path+'/'+files):
                im_path = cat_path + '/' + files
                im = skiData.imread(im_path)
# Out:
# Loading files from path: /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/airplanes/
# Loading files from path:
#  /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/bat/
# Loading files from path:
#  /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/bear/
# Loading files from path:
#  /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/blimp/
# Loading files from path:
#  /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/camel/
# Loading files from path:
#  /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/comet/
# Loading files from path:
#  /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/conch/
# Loading files from path:
#  /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/cormorant/
# Loading files from path:
#  /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4/50_categories/crab/
# ...

# %%
print os.getcwd()
# Out:
# /Users/Anders/Documents/Courses/AY 250/Homework/Homework 4

# %%
len([name for name in os.listdir(os.getcwd()+'/50_categories/')])
# Out:
# 51

# %%
import skimage.data as ski

# %%
im = ski.imread(im_path)

# %%
import skimage.filter as ft

imshow(ft.hsobel(np.median(im,axis=2)))

# %%
class trysomething:
    
    def __init__():
        print "initializing"
        
    def number1():
        print "trying one"
        
    def number2():
        print "trying two"
        
for callable in trysomething.__dict__.values():
    try:
        print callable.func_name
        callable()    
    except TypeError:
        pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-582f0c23898a> in <module>()
#      12 for callable in trysomething.__dict__.values():
#      13     try:
# ---> 14         print callable().func_name
#      15         callable()
#      16     except TypeError:
#
# AttributeError: 'NoneType' object has no attribute 'func_name'
# trying two
